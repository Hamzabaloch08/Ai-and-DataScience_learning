# %% [markdown]
# # logical Operator
# - not
# - or
# - and

# %%
12 > 10
# Out:
# True

# %%
(12 > 10) or (day=="sunday")
# Out:
# True

# %% [raw]
# exp1 OR exp2     Result
# True    True     True
# True    False    True
# False   True     True
# False   False    False
#
# NOTE: OR needs ONE True to make expression TRUE.
#
# exp1 AND exp2    Result
# True    True     True
# True    False    False
# False   True     False
# False   False    False
#
# NOTE: AND needs ONE False to make expression FALSE.

# %% [markdown]
# # pamdas rule:
#
# - power
# - add
# - multiply
# - divide
# - subtract

# %%
age = input("enter your age: ")
age
# Out:
# enter your age:  2
# '2'

# %%
age = int(input("enter your age: "))
age
# Out:
# enter your age:  34
# 34

# %%
age = float(input("enter your age: "))
age
# Out:
# enter your age:  324.324
# 324.324
